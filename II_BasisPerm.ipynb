# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator, Aer
from qiskit.quantum_info import Statevector
from qiskit.circuit.library import MCXGate


from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_distribution 

import numpy as np
from math import pi

# %%
qc = QuantumCircuit(5)

qc.h(0)
qc.h(1)
qc.barrier()
#Indexing

#00
qc.x(0)
qc.x(1)
qc.x(2)
qc.x(3)
gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(0)
qc.x(1)
qc.x(2)
qc.x(3)
qc.barrier()

qc.cx(4,1)
qc.cx(4,2)

qc.barrier()

gate = MCXGate(4)
qc.x(0)
qc.x(3)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(3)
qc.x(0)
qc.barrier()
qc.barrier()

#01
qc.x(1)
qc.x(2)
qc.x(3)
gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(1)
qc.x(2)
qc.x(3)
qc.barrier()

qc.cx(4,3)

qc.barrier()

qc.x(1)
qc.x(2)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(2)
qc.x(1)
qc.barrier()
qc.barrier()

#10
qc.x(0)
qc.x(2)
qc.x(3)
gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(0)
qc.x(2)
qc.x(3)
qc.barrier()

qc.cx(4,0)
qc.cx(4,2)
qc.cx(4,3)

qc.barrier()

qc.append(gate, [0, 1, 2, 3, 4])


#11



qc.draw('mpl',fold=240)

# %%
simulator = Aer.get_backend('statevector_simulator')
result=simulator.run(qc.decompose()).result()
counts = result.get_counts()
print("\nTotal count are:",counts)
plot_distribution(counts)
# Out:
# Total count are: {np.str_('00011'): np.float64(0.249999999999998), np.str_('00110'): np.float64(0.249999999999998), np.str_('01001'): np.float64(0.249999999999997), np.str_('01111'): np.float64(0.249999999999997)}

# %%
qc.depth()
# Out:
# 23
