# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator, Aer
from qiskit.quantum_info import Statevector
from qiskit.circuit.library import MCXGate


from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_distribution 

import numpy as np
from math import pi

# %%
qc = QuantumCircuit(5)

qc.h(0)
qc.h(1)
qc.barrier()
#Indexing

#00
qc.x(0)
qc.x(2)
qc.x(3)
gate = MCXGate(3)
qc.append(gate, [0,  2, 3, 4])
qc.x(0)
qc.x(2)
qc.x(3)

qc.barrier()

qc.cx(4,2)

qc.barrier()

qc.draw('mpl',fold=240)

# %%
simulator = Aer.get_backend('statevector_simulator')
result=simulator.run(qc.decompose()).result()
counts = result.get_counts()
print("\nTotal count are:",counts)
plot_distribution(counts)
# Out:
# Total count are: {np.str_('00001'): np.float64(0.25), np.str_('00011'): np.float64(0.25), np.str_('10100'): np.float64(0.25), np.str_('10110'): np.float64(0.25)}

# %%
qc = QuantumCircuit(5)

qc.h(0)
qc.h(1)
qc.barrier()
#Indexing

#00
qc.x(0)
qc.x(2)
qc.x(3)
gate = MCXGate(3)
qc.append(gate, [0,  2, 3, 4])
qc.x(0)
qc.x(2)
qc.x(3)


qc.barrier()

qc.cx(4,2)

qc.barrier()

#Disentangle


qc.x(0)
qc.x(3)
gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(3)
qc.x(0)


qc.barrier()
#Another Adress

qc.draw('mpl',fold=240)

# %%
simulator = Aer.get_backend('statevector_simulator')
result=simulator.run(qc.decompose()).result()
counts = result.get_counts()
print("\nTotal count are:",counts)
plot_distribution(counts)
# Out:
# Total count are: {np.str_('00001'): np.float64(0.249999999999999), np.str_('00011'): np.float64(0.249999999999999), np.str_('00110'): np.float64(0.25), np.str_('10100'): np.float64(0.249999999999999)}

# %%
qc = QuantumCircuit(5)

qc.h(0)
qc.h(1)
qc.barrier()
#Indexing

#00
qc.x(0)
qc.x(2)
qc.x(3)
gate = MCXGate(3)
qc.append(gate, [0,  2, 3, 4])
qc.x(0)
qc.x(2)
qc.x(3)


qc.barrier()

qc.cx(4,2)

qc.barrier()

#Disentangle


qc.x(0)
qc.x(3)
gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(3)
qc.x(0)


qc.barrier()
#Another Adress

qc.cx(4,0)
qc.cx(4,1)

qc.barrier()

qc.draw('mpl',fold=240)

# %%
simulator = Aer.get_backend('statevector_simulator')
result=simulator.run(qc.decompose()).result()
counts = result.get_counts()
print("\nTotal count are:",counts)
plot_distribution(counts)
# Out:
# Total count are: {np.str_('00001'): np.float64(0.249999999999999), np.str_('00011'): np.float64(0.249999999999999), np.str_('00110'): np.float64(0.25), np.str_('10111'): np.float64(0.249999999999999)}

# %%
qc = QuantumCircuit(5)

qc.h(0)
qc.h(1)
qc.barrier()
#Indexing

#00
qc.x(0)
qc.x(2)
qc.x(3)
gate = MCXGate(3)
qc.append(gate, [0,  2, 3, 4])
qc.x(0)
qc.x(2)
qc.x(3)

qc.barrier()

qc.cx(4,2)

qc.barrier()

#Disentangle


qc.x(0)
qc.x(3)
gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(3)
qc.x(0)


qc.barrier()
#Another Adress

qc.cx(4,0)
qc.cx(4,1)

qc.barrier()

#Another Adress

qc.x(1)
qc.x(2)
qc.x(3)
gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(1)
qc.x(2)
qc.x(3)

qc.barrier()

qc.cx(4,3)

qc.draw('mpl',fold=240)

# %%
simulator = Aer.get_backend('statevector_simulator')
result=simulator.run(qc.decompose()).result()
counts = result.get_counts()
print("\nTotal count are:",counts)
plot_distribution(counts)
# Out:
# Total count are: {np.str_('00011'): np.float64(0.249999999999999), np.str_('00110'): np.float64(0.249999999999999), np.str_('11001'): np.float64(0.249999999999999), np.str_('11111'): np.float64(0.249999999999999)}

# %%
qc = QuantumCircuit(5)

qc.h(0)
qc.h(1)
qc.barrier()
#Indexing

#00
qc.x(0)
qc.x(2)
qc.x(3)
gate = MCXGate(3)
qc.append(gate, [0,  2, 3, 4])
qc.x(0)
qc.x(2)
qc.x(3)

qc.barrier()

qc.cx(4,2)

qc.barrier()

#Disentangle


qc.x(0)
qc.x(3)
gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(3)
qc.x(0)


qc.barrier()
#Another Adress

qc.cx(4,0)
qc.cx(4,1)
qc.barrier()

#Another Adress

qc.x(1)
qc.x(2)
qc.x(3)
gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(1)
qc.x(2)
qc.x(3)

qc.barrier()
qc.cx(4,3)
qc.barrier()

#Disentangl


gate = MCXGate(2)
qc.append(gate, [0, 3, 4])

qc.draw('mpl',fold=240)

# %%
simulator = Aer.get_backend('statevector_simulator')
result=simulator.run(qc.decompose()).result()
counts = result.get_counts()
print("\nTotal count are:",counts)
plot_distribution(counts)
# Out:
# Total count are: {np.str_('00011'): np.float64(0.249999999999999), np.str_('00110'): np.float64(0.249999999999999), np.str_('01001'): np.float64(0.249999999999999), np.str_('01111'): np.float64(0.249999999999999)}

# %%
qc.depth()
# Out:
# 15

# %%
qc = QuantumCircuit(5)

qc.h(0)
qc.h(1)
qc.barrier()
#Indexing

#00
qc.x(0)
qc.x(2)
qc.x(3)
gate = MCXGate(3)
qc.append(gate, [0,  2, 3, 4])

qc.x(2)


qc.barrier()

qc.cx(4,2)

qc.barrier()

#Disentangle

gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])

qc.x(0)


qc.barrier()
#Another Adress

qc.cx(4,0)
qc.cx(4,1)
qc.barrier()

#Another Adress

qc.x(1)
qc.x(2)

gate = MCXGate(4)
qc.append(gate, [0, 1, 2, 3, 4])
qc.x(1)
qc.x(2)
qc.x(3)

qc.barrier()
qc.cx(4,3)
qc.barrier()

#Disentangl


gate = MCXGate(2)
qc.append(gate, [0, 3, 4])

qc.draw('mpl',fold=240)

# %%
simulator = Aer.get_backend('statevector_simulator')
result=simulator.run(qc.decompose()).result()
counts = result.get_counts()
print("\nTotal count are:",counts)
plot_distribution(counts)
# Out:
# Total count are: {np.str_('00011'): np.float64(0.249999999999999), np.str_('00110'): np.float64(0.249999999999999), np.str_('01001'): np.float64(0.249999999999999), np.str_('01111'): np.float64(0.249999999999999)}

# %%
qc.depth()
# Out:
# 14
